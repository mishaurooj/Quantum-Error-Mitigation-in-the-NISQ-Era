# %% [markdown]
# **	A. Ideal Simulator vs. Quantum Computer Results (Osaka & Kyoto) without Error Mitigation Technique**

# %%
import matplotlib.pyplot as plt

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
qasm_simulator = [0.982, 0.936, 0.836, 0.762, 0.626, 0.8284	]
ibm_osaka = [0.628, 0.166, 0.044, 0.2492, 0.598,0.33704	 ]
ibm_kyoto = [0.358, 0.05, 0.044, 0.1828, 0.4642,0.2198	 ]
percent_osaka = [35.90, 82.33, 94.72, 67.30, 4.47,56.94	 ]
percent_kyoto = [63.57, 94.66, 94.72, 76.04, 25.82, 70.96]


# Plotting the bar graph
x = range(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x, qasm_simulator, width, label='$SIM_{IBMQ}$', color='g')
ax1.bar([i + width for i in x], ibm_osaka, width, label='$IBM_{O}$', color='b')
ax1.bar([i + 2*width for i in x], ibm_kyoto, width, label='$IBM_{K}$', color='r')

ax1.set_ylabel('Estimator Result Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks([i + width for i in x])
ax1.set_xticklabels(labels, fontsize=8)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x, percent_osaka, marker='o', linestyle='-', color='c', label='% Δ $SIM_{IBMQ}$ VS $IBM_{O}$ ')
ax2.plot(x, percent_kyoto, marker='o', linestyle='-', color='m', label='% Δ $SIM_{IBMQ}$ VS $IBM_{K}$ ')

ax2.set_ylabel('% Difference')

# Setting legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(a) Comparsion of estimator result values and % differences ', fontsize=12, pad=20)
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
qasm_sigma2 = [0.03567, 0.1239, 0.3011, 0.41935, 0.60812, 0.297628	]
ibm_osaka_sigma2 = [0.0591, 0.1828, 0.2638, 0.31358, 0.31358,0.226572	]
ibm_kyoto_sigma2 = [0.2638, 0.4642, 0.598, 0.31358, 0.31358, 0.390632	 ]
percent_osaka = [65.14, 47.56, 12.38, 25.34, 48.41, 39.77	 ]
percent_kyoto = [637.37, 275.38, 98.46, 25.34, 48.41, 216.99]

# Plotting the bar graph
x = range(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x, qasm_sigma2, width, label='$SIM_{IBMQ}$', color='g')
ax1.bar([i + width for i in x], ibm_osaka_sigma2, width, label='$IBM_{O}$', color='b')
ax1.bar([i + 2*width for i in x], ibm_kyoto_sigma2, width, label='$IBM_{K}$', color='r')

ax1.set_ylabel('Variance Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks([i + width for i in x])
ax1.set_xticklabels(labels, fontsize=10)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x, percent_osaka, marker='o', linestyle='-', color='c', label='% Δ $SIM_{IBMQ}$ VS $IBM_{O}$')
ax2.plot(x, percent_kyoto, marker='o', linestyle='-', color='m', label='% Δ $SIM_{IBMQ}$ VS $IBM_{K}$')

ax2.set_ylabel('% Difference')

# Setting legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(b) Comparison of variance values and % differences', fontsize=12, pad=20)
plt.grid(True)

# Adjust layout to fit legend inside the graph grid
plt.tight_layout()

plt.show()

# %% [markdown]
# **	B. Ideal Simulator vs. IBM Kyoto Results with Error Mitigation Techniques**

# %%
import matplotlib.pyplot as plt

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
ideal_simulator = [0.982, 0.936, 0.836, 0.762, 0.626, 0.8284]
ibm_kyoto_dd = [0.318, 0.224, 0.168, 0.114, 0.04, 0.1728	 ]
ibm_kyoto_trex = [0.813, 0.363, 0.3, 0.292, 0.015795, 0.356759	]
ibm_kyoto_zne = [0.25, 0.11, 0.137, 0.023, 0.03016, 0.110032	]
percent_dd = [67.59, 76.06, 79.88, 85.03, 93.58, 80.43	 ]
percent_trex = [17.20, 61.08, 64.01, 61.63, 97.48, 60.28	]
percent_zne = [74.52, 88.26, 83.61, 96.99, 95.18,87.71  ]

# Plotting the bar graph
x = range(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x, ideal_simulator, width, label='$SIM_{IBMQ}$', color='g')
ax1.bar([i + width for i in x], ibm_kyoto_dd, width, label='$IBM_{K}$ (DD)', color='lightgreen')
ax1.bar([i + 2*width for i in x], ibm_kyoto_trex, width, label='$IBM_{K}$ (T-REx)', color='salmon')
ax1.bar([i + 3*width for i in x], ibm_kyoto_zne, width, label='$IBM_{K}$ (ZNE)', color='gold')

ax1.set_ylabel('Estimator Result Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks([i + 1.5*width for i in x])
ax1.set_xticklabels(labels, fontsize=10)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x, percent_dd, marker='o', linestyle='-', color='darkblue', label='% Δ $SIM_{IBMQ}$ VS $IBM_{K}$ (DD)')
ax2.plot(x, percent_trex, marker='o', linestyle='-', color='darkgreen', label='% Δ $SIM_{IBMQ}$ VS $IBM_{K}$ (T-REx)')
ax2.plot(x, percent_zne, marker='o', linestyle='-', color='darkred', label='% Δ $SIM_{IBMQ}$ VS $IBM_{K}$ (ZNE)')

ax2.set_ylabel('% Difference')

# Adding legends in one box
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(a) Comparison of expectation values and % differences')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
ideal_simulator_sigma2 = [0.03567, 0.1239, 0.3011, 0.41935, 0.60812, 0.297628	 ]
ibm_kyoto_dd_sigma2 = [0.898876, 0.949824, 0.971776, 0.987004, 0.9984,0.961176	 ]
ibm_kyoto_trex_sigma2 = [0.1728, 0.356759, 0.961932, 0.96, 0.96, 0.6822982	]
ibm_kyoto_zne_sigma2 = [0.25, 0.110032, 0.137, 0.023, 0.03016,0.1100384	 ]
percent_dd = [2404.42, 667.32, 223.09, 135.82, 64.18,698.97	 ]
percent_trex = [384.64, 187.35, 219.90, 128.71, 57.95,195.71	 ]
percent_zne = [600.16, 87.75, 54.46, 99.45, 95.04, 187.37]

# Plotting the bar graph
x = range(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x, ideal_simulator_sigma2, width, label='$SIM_{IBMQ}$', color='g')
ax1.bar([i + width for i in x], ibm_kyoto_dd_sigma2, width, label='$IBM_{K}$ (DD)', color='lightgreen')
ax1.bar([i + 2*width for i in x], ibm_kyoto_trex_sigma2, width, label='$IBM_{K}$ (T-REx)', color='salmon')
ax1.bar([i + 3*width for i in x], ibm_kyoto_zne_sigma2, width, label='$IBM_{K}$ (ZNE)', color='gold')


ax1.set_ylabel('Varaince Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks([i + 1.5*width for i in x])
ax1.set_xticklabels(labels, fontsize=10)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x, percent_dd, marker='o', linestyle='-', color='darkblue', label='% Δ $SIM_{IBMQ}$ VS $IBM_{K}$ (DD)')
ax2.plot(x, percent_trex, marker='o', linestyle='-', color='darkgreen', label='% Δ $SIM_{IBMQ}$ VS $IBM_{K}$ (T-REx)')
ax2.plot(x, percent_zne, marker='o', linestyle='-', color='darkred', label='% Δ $SIM_{IBMQ}$ VS $IBM_{K}$ (ZNE)')
ax2.set_ylabel('% Difference')

# Adding legends in one box
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(b) Comparison of variance values and % differences')
plt.grid(True)

plt.show()

# %% [markdown]
# # **	C. IBM Kyoto Results without Error Mitigation vs. Error Mitigation Techniques**

# %%
import matplotlib.pyplot as plt

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
no_mitigation = [0.156, 0.134, 0.13, 0.018, 0.012, 0.09	]
dd = [0.318, 0.224, 0.168, 0.114, 0.04, 0.1728	 ]
trex = [0.813, 0.363, 0.3, 0.292, 0.015795,0.356759	 ]
zne = [0.25, 0.11, 0.137, 0.023, 0.03016,0.110032	 ]
percent_dd = [104.49, 67.16, 29.23, 533.33, 233.33, 193.51	]
percent_trex = [421.15, 171.64, 130.77, 1522.22, 31.63, 455.48	]
percent_zne = [60.26, 17.91, 5.38, 27.78, 151.33, 52.53  ]

# Plotting the bar graph
x = range(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x, no_mitigation, width, label='$IBM_{K}$ (No Mitigation)', color='#ff7f0e')
ax1.bar([i + width for i in x], dd, width, label='$IBM_{K}$ (DD)', color='lightgreen')
ax1.bar([i + 2*width for i in x], trex, width, label='$IBM_{K}$ (T-REx)', color='salmon')
ax1.bar([i + 3*width for i in x], zne, width, label='$IBM_{K}$ (ZNE)', color='gold')

ax1.set_ylabel('Estimator Result Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks([i + 1.5*width for i in x])
ax1.set_xticklabels(labels, fontsize=10)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x, percent_dd, marker='o', linestyle='-', color='darkblue', label='% Δ $IBM_{K}$ (No Mitigation) VS $IBM_{K}$ (DD)')
ax2.plot(x, percent_trex, marker='o', linestyle='-', color='darkgreen', label='% Δ $IBM_{K}$ (No Mitigation) VS $IBM_{K}$ (T-REx)')
ax2.plot(x, percent_zne, marker='o', linestyle='-', color='darkred', label='% Δ $IBM_{K}$ (No Mitigation) VS $IBM_{K}$ (ZNE)')

ax2.set_ylabel('% Difference')

# Adding legends in one box
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(a) Comparison of estimator result values and % differences')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
no_mitigation_sigma2 = [0.982044, 0.9831, 0.999676, 0.999856, 0.999856,0.9929064	 ]
dd_sigma2 = [0.898876, 0.949824, 0.971776, 0.987004, 0.9984, 0.961176	 ]
trex_sigma2 = [15.183124, 15.712896, 15.754814, 15.759492, 15.844637, 15.6509926	]
zne_sigma2 = [0.949824, 0.96, 0.979836, 0.96, 0.96, 0.961932	 ]
percent_dd = [8.47, 3.39, 2.79, 1.29, 0.14, 3.22	 ]
percent_trex = [1444.41, 1499.79, 1475.52, 1475.95, 1584.02,1495.94	 ]
percent_zne = [3.30, 2.34, 2.01, 3.90, 3.90,3.09 ]

# Plotting the bar graph
x = range(len(labels))
width = 0.2

fig, ax1 = plt.subplots()
ax1.bar(x, no_mitigation_sigma2, width, label='$IBM_{K}$ (No Mitigation)', color='#ff7f0e')
ax1.bar([i + width for i in x], dd_sigma2, width, label='$IBM_{K}$ (DD)', color='lightgreen')
ax1.bar([i + 2*width for i in x], trex_sigma2, width, label='$IBM_{K}$ (T-REx)', color='salmon')
ax1.bar([i + 3*width for i in x], zne_sigma2, width, label='$IBM_{K}$ (ZNE)', color='gold')


ax1.set_ylabel('Varaince Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks([i + 1.5*width for i in x])
ax1.set_xticklabels(labels, fontsize=10)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x, percent_dd, marker='o', linestyle='-', color='darkblue', label='% Δ $IBM_{K}$ (No Mitigation) VS $IBM_{K}$ (DD)')
ax2.plot(x, percent_trex, marker='o', linestyle='-', color='darkgreen', label='% Δ $IBM_{K}$ (No Mitigation) VS $IBM_{K}$ (T-REx)')
ax2.plot(x, percent_zne, marker='o', linestyle='-', color='darkred', label='% Δ $IBM_{K}$ (No Mitigation) VS $IBM_{K}$ (ZNE)')

ax2.set_ylabel('% Difference')

# Adding legends in one box
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(b) Comparison of variance values and % differences')
plt.grid(True)

plt.show()

# %% [markdown]
# **	D. Ideal Simulator vs. IBM Osaka Results with Error Mitigation Techniques.**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
ideal_simulator = [0.982, 0.936, 0.836, 0.762, 0.626,0.8284	]
dd = [0.686, 0.508, 0.354, 0.21, 0.136, 0.3788	 ]
trex = [0.7945, 0.4704, 0.168, 0.0648, 0.01, 0.30154	 ]
zne = [0.7586, 0.4626, 0.1684, 0.079, 0.0132, 0.29636	]
percent_dd = [30.11, 45.66, 57.59, 72.47, 78.26,56.82	 ]
percent_trex = [19.04, 49.71, 79.92, 91.48, 115.37, 71.10	 ]
percent_zne = [22.75, 50.54, 79.88, 89.64, 97.89,68.14 ]

# Define colors using the plasma color map
colors = plt.cm.plasma(np.linspace(0, 1, 7))

# Plotting the bar graph
x = np.arange(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x - 1.5*width, ideal_simulator, width, label='$SIM_{IBMQ}$', color='g')
ax1.bar(x - 0.5*width, dd, width, label='$IBM_{O}$ (DD)', color='pink')
ax1.bar(x + 0.5*width, trex, width, label='$IBM_{O}$ (T-REx)', color='purple')
ax1.bar(x + 1.5*width, zne, width, label='$IBM_{O}$ (ZNE)', color='darkblue')


ax1.set_ylabel('Estimator Result Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks(x)
ax1.set_xticklabels(labels, fontsize=10)


# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x, percent_dd, marker='o', linestyle='-', color='darkblue', label='% Δ $SIM_{IBMQ}$ VS $IBM_{O}$ (DD)')
ax2.plot(x, percent_trex, marker='o', linestyle='-', color='darkgreen', label='% Δ $SIM_{IBMQ}$ VS $IBM_{O}$ (T-REx)')
ax2.plot(x, percent_zne, marker='o', linestyle='-', color='darkred', label='% Δ $SIM_{IBMQ}$ VS $IBM_{O}$ (ZNE)')
ax2.set_ylabel('% Values')


# Adding legends in one box
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(a) Comparison of estimator result values and % differences')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
ideal_simulator_sigma2 = [0.03567, 0.1239, 0.3011, 0.41935, 0.60812,0.297628	]
dd_sigma2 = [0.6056, 0.8718, 0.9724, 0.88908, 0.9975, 0.867276	]
trex_sigma2 = [0.5294, 0.742, 0.8747, 0.8167, 0.9559, 0.78374	 ]
zne_sigma2 = [0.4567, 0.8234, 0.9156, 0.83874, 0.9987, 0.806628	]
percent_dd = [1596.47, 602.54, 222.10, 112.96, 64.17, 519.65]
percent_trex = [1388.60, 498.19, 190.77, 94.57, 57.28, 445.88 ]
percent_zne = [1179.05, 565.73, 204.26, 99.92, 64.45,422.68 ]

# Define colors using the plasma color map
colors = plt.cm.plasma(np.linspace(0, 1, 7))

# Plotting the bar graph
x = np.arange(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x - 1.5*width, ideal_simulator_sigma2, width, label='$SIM_{IBMQ}$', color='g')
ax1.bar(x - 0.5*width, dd_sigma2, width, label='$IBM_{O}$ (DD)', color='pink')
ax1.bar(x + 0.5*width, trex_sigma2, width, label='$IBM_{O}$ (T-REx)', color='purple')
ax1.bar(x + 1.5*width, zne_sigma2, width, label='$IBM_{O}$ (ZNE)', color='darkblue')


ax1.set_ylabel('Varaince Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks(x)
ax1.set_xticklabels(labels, fontsize=10)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x - 1.5*width, percent_dd, marker='o', linestyle='-', color='darkblue', label='% Δ $SIM_{IBMQ}$ VS $IBM_{O}$ (DD)')
ax2.plot(x - 0.5*width, percent_trex, marker='o', linestyle='-', color='darkgreen', label='% Δ $SIM_{IBMQ}$ VS $IBM_{O}$ (T-REx)')
ax2.plot(x + 0.5*width, percent_zne, marker='o', linestyle='-', color='darkred', label='% Δ $SIM_{IBMQ}$ VS $IBM_{O}$ (ZNE)')

ax2.set_ylabel('% Difference')


# Adding legends in one box
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(b) Comparison of variance values and % differences')
plt.grid(True)

plt.show()

# %% [markdown]
# # **	E. IBM Osaka Results without Error Mitigation vs. Error Mitigation Techniques**

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
no_mitigation = [0.628, 0.358, 0.166, 0.05, 0.044, 0.2492	]
dd = [0.686, 0.508, 0.354, 0.21, 0.136, 0.3788	]
trex = [0.7945, 0.4704, 0.168, 0.0648, 0.01, 0.30154	 ]
zne = [0.7586, 0.4626, 0.1684, 0.079, 0.0132, 0.29636	 ]
percent_dd = [9.24, 41.90, 113.25, 320.00, 209.09, 138.70	 ]
percent_trex = [26.69, 31.43, 1.20, 29.60, 318.18, 81.42	]
percent_zne = [20.84, 29.13, 1.44, 58.00, 70.91, 36.06]

# Define colors using the tab10 color map
colors = plt.cm.tab10(np.linspace(0, 1, 7))

# Plotting the bar graph
x = np.arange(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x - 1.5*width, no_mitigation, width, label='$IBM_{O}$ (No Mitigation)', color='red')
ax1.bar(x - 0.5*width, dd, width, label='$IBM_{O}$ (DD)', color='pink')
ax1.bar(x + 0.5*width, trex, width, label='$IBM_{O}$ (T-REx)', color='purple')
ax1.bar(x + 1.5*width, zne, width, label='$IBM_{O}$ (ZNE)', color='darkblue')

ax1.set_ylabel('Estimator Result Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks(x)
ax1.set_xticklabels(labels, fontsize=10)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x - 1.5*width, percent_dd, marker='o', linestyle='-', color='darkblue', label='% Δ $IBM_{O}$ (No Mitigation) VS $IBM_{O}$ (DD)')
ax2.plot(x - 0.5*width, percent_trex, marker='o', linestyle='-', color='darkgreen', label='% Δ $IBM_{O}$ (No Mitigation) VS $IBM_{O}$ (T-REx)')
ax2.plot(x + 0.5*width, percent_zne, marker='o', linestyle='-', color='darkred', label='% Δ $IBM_{O}$ (No Mitigation)VS $IBM_{O}$ (ZNE)')

ax2.set_ylabel('% Difference')

# Adding legends in one box
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(a) Comparison of estimator result values and % differences')
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
labels = ['$TC_1$', '$TC_2$', '$TC_3$', '$TC_4$', '$TC_5$', 'Average']
no_mitigation_sigma2 = [0.0591, 0.1828, 0.2638, 0.31358, 0.4642, 0.256696	]
dd_sigma2 = [0.6056, 0.8718, 0.9724, 0.88908, 0.9975, 0.867276	 ]
trex_sigma2 = [0.5294, 0.742, 0.8747, 0.8167, 0.9559, 0.78374	 ]
zne_sigma2 = [0.4567, 0.8234, 0.9156, 0.83874, 0.9987, 0.806628	 ]
percent_dd = [924.05, 377.99, 269.38, 183.68, 115.61, 374.14]
percent_trex = [796.94, 304.08, 231.92, 160.42, 106.78, 320.03 ]
percent_zne = [673.90, 350.62, 246.31, 167.37, 115.76, 310.79 ]

# Define colors using the tab10 color map
colors = plt.cm.tab10(np.linspace(0, 1, 7))

# Plotting the bar graph
x = np.arange(len(labels))
width = 0.2

fig, ax1 = plt.subplots()

ax1.bar(x - 1.5*width, no_mitigation_sigma2, width, label='$IBM_{O}$ (No Mitigation)', color='red')
ax1.bar(x - 0.5*width, dd_sigma2, width, label='$IBM_{O}$ (DD)', color='pink')
ax1.bar(x + 0.5*width, trex_sigma2, width, label='$IBM_{O}$ (T-REx)', color='purple')
ax1.bar(x + 1.5*width, zne_sigma2, width, label='$IBM_{O}$ (ZNE)', color='darkblue')

ax1.set_ylabel('Variance Values')
ax1.set_xlabel('Trotter Circuits')
ax1.set_xticks(x)
ax1.set_xticklabels(labels, fontsize=10)

# Plotting the line graph
ax2 = ax1.twinx()
ax2.plot(x - 1.5*width, percent_dd, marker='o', linestyle='-', color='darkblue', label='% Δ $IBM_{O}$ (No Mitigation) VS $IBM_{O}$ (DD)')
ax2.plot(x - 0.5*width, percent_trex, marker='o', linestyle='-', color='darkgreen', label='% Δ $IBM_{O}$ (No Mitigation) VS $IBM_{O}$ (T-REx)')
ax2.plot(x + 0.5*width, percent_zne, marker='o', linestyle='-', color='darkred', label='% Δ $IBM_{O}$ (No Mitigation) VS $IBM_{O}$ (ZNE)')

ax2.set_ylabel('% Difference')

# Adding legends in one box
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='upper right', fontsize=8)

plt.title('(b) Comparison of variance values and % differences')
plt.grid(True)

plt.show()
